# %% [markdown]
# # TP1 TRIVA - Louis Montaut

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Showing the colored image

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %%
Irgb = mpimg.imread('images/rock2.png')
fig = plt.figure(figsize=(8,8))
plt.axis('off')
plt.title('Normal Image')
imgplot = plt.imshow(Irgb)
plt.show()

# %%
if not os.path.exists("results"):
    os.makedirs("results")

# %% [markdown]
# ### Black and white

# %%
def get_luminance(Irgb):
    return np.dot(Irgb[...,:3], [0.2126, 0.7152, 0.0722])

# %%
I = get_luminance(Irgb)
fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('RGB Image')
plt.imshow(Irgb)

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Black and White Image')
plt.imshow(I, cmap = plt.get_cmap('gray'))

plt.show()

fig.savefig('results/black_and_white.png')

# %% [markdown]
# ## Basic image processing

# %% [markdown]
# ### Noise

# %%
sigma_noise = 0.1
n,m = I.shape
I_noise = I + np.random.randn(n,m)*sigma_noise

fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('Normal image Image')
plt.imshow(I, cmap=plt.get_cmap('gray'))

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Image with Noise')
plt.imshow(I_noise, cmap=plt.get_cmap('gray'))

plt.show()

fig.savefig('results/noise.png')

# %% [markdown]
# ### Gaussian convolution

# %%
import gaussian_convolution as gc
I_blurred = gc.gaussianConvolution(I,2)

fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('Normal Image')
plt.imshow(I, cmap=plt.get_cmap('gray'))

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Blurred Image')
plt.imshow(I_blurred, cmap=plt.get_cmap('gray'))

plt.show()

fig.savefig('results/gaussian_convolution.png')

# %% [markdown]
# ### Gradient

# %% [markdown]
# Here, I made the code so that we can compute the gradient using two techniques.<br>
# The first one **computeGradientNoConvolution** doesn't use kernels to compute the gradient. It just uses the standard finite differences.<br>
# The second one **computeGradient** uses convolution to compute the gradient.

# %%
from gradient import computeGradient, computeGradientNoConvolution
threshold = 0.08

I_gradient = computeGradientNoConvolution(I_blurred)
#I_gradient = computeGradient(I_blurred)
dIx,dIy,dI_norm,dI_orientation = I_gradient.dIx,I_gradient.dIy,I_gradient.dI_norm,I_gradient.dI_orientation

n,m = dI_norm.shape
dI_norm_threshold = np.zeros((n,m))

for i in range(n):
    for j in range(m):
        if dI_norm[i,j]>threshold:
            dI_norm_threshold[i,j]=dI_norm[i,j]
        
            
fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('Original Image')
plt.imshow(I, cmap=plt.get_cmap('gray'))

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Gradient Norm under Threshold')
plt.imshow(dI_norm_threshold, cmap=plt.get_cmap('gray'))

plt.show()

fig.savefig('results/threshold_gradient.png')

# %% [markdown]
# ## Canny Edge Detector

# %% [markdown]
# ### Quantify Gradient

# %%
from quantify_gradient import quantifyGradient
I_quantified_gradient = quantifyGradient(dI_orientation)

orientation = 4

n,m = I_quantified_gradient.shape
I_orientation = np.zeros((n,m))
for i in range(n):
    for j in range(m):
        if I_quantified_gradient[i,j] == orientation:
            I_orientation[i,j] = 1
        else :
            I_orientation[i,j] = 0

# %%
fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('Gradient Norm')
plt.imshow(dI_norm, cmap=plt.get_cmap('gray'))

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Orientation quantified')
plt.imshow(I_orientation, cmap=plt.get_cmap('gray'))

plt.show()

# %% [markdown]
# ### Non-max Suppression

# %%
from non_max_supression import nms
I_nms = nms(dI_norm, I_quantified_gradient, threshold)

            
fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('Gradient with threshold')
plt.imshow(dI_norm_threshold, cmap=plt.get_cmap('gray'))

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Non-max Supression')
plt.imshow(I_nms, cmap=plt.get_cmap('gray'))

plt.show()

# %% [markdown]
# ### Canny Edges Detector

# %%
from canny_edges import cannyEdges
sigma = 2
t1 = threshold
t2 = 0.008
Edges = cannyEdges(I,sigma,t1,t2)

fig = plt.figure(figsize=(15,15))

fig.add_subplot(1,2,1)
plt.axis('off')
plt.title('Non-max Supression')
plt.imshow(I_nms, cmap=plt.get_cmap('gray'))

fig.add_subplot(1,2,2)
plt.axis('off')
plt.title('Canny Edges Detection')
plt.imshow(Edges, cmap=plt.get_cmap('gray'))

plt.show()
